# %% [markdown]
# ## a + b)

# %%
require(ggplot2)
require(reshape)
# Out:
# Loading required package: ggplot2
# Loading required package: reshape

# %%
n <- 15
xs <- 0:n
ps <- seq(0.1, 0.9, 0.1)

# %%
df <- data.frame(x=xs, sapply(ps, dbinom, x=xs, size=n))
df <- melt(df, id.vars='x', variable_name='distr')

# %%
ggplot(df, aes(x, value)) + geom_point() + facet_grid(distr ~ .)
# Out:
# plot without title

# %% [markdown]
# ## c)

# %%
ns <- c(10, 20, 50, 200)
p <- 0.05

# %%
df <- data.frame(x=0:200, sapply(ns, dbinom, x=0:200, prob=p))
df <- melt(df, id.vars='x', variable_name='distr')

# %%
ggplot(df, aes(x, value)) + geom_point() + facet_grid(distr ~ .)
# Out:
# plot without title
