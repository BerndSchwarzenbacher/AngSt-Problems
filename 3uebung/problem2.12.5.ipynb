# %%
require(ggplot2)
require(reshape)
# Out:
# Loading required package: ggplot2
# Loading required package: reshape

# %%
n <- 100
lambda <- 2
p <- 0.02

# %%
dat <- data.frame(x=0:n, pois=dpois(0:n, lambda), binom=dbinom(0:n, n, p))
df <- melt(dat, id.vars='x', variable_name='distr')

# %%
ggplot(df, aes(x, value, color=distr)) + geom_point()
# Out:
# plot without title
