# %%
data <- scan("rn01.txt")

# %%
class <- cut(data, breaks=c(-Inf, qnorm((1:7)/8), Inf))
class
# Out:
#  [1] (-0.319,0]      (-1.15,-0.674]  (0.674,1.15]    (-1.15,-0.674]
#  [5] (-1.15,-0.674]  (-Inf,-1.15]    (0.674,1.15]    (-1.15,-0.674]
#  [9] (-Inf,-1.15]    (0.674,1.15]    (1.15, Inf]     (0.319,0.674]
# [13] (0,0.319]       (-1.15,-0.674]  (-1.15,-0.674]  (1.15, Inf]
# [17] (1.15, Inf]     (-0.674,-0.319] (0.674,1.15]    (0,0.319]
# [21] (-0.674,-0.319] (-1.15,-0.674]  (0,0.319]       (-Inf,-1.15]
# [25] (-Inf,-1.15]    (1.15, Inf]     (-0.319,0]      (1.15, Inf]
# [29] (-0.319,0]      (0,0.319]       (0.674,1.15]    (-0.319,0]
# [33] (-0.674,-0.319] (1.15, Inf]     (-1.15,-0.674]  (0.674,1.15]
# [37] (-0.674,-0.319] (0.674,1.15]    (0.674,1.15]    (-1.15,-0.674]
# 8 Levels: (-Inf,-1.15] (-1.15,-0.674] (-0.674,-0.319] (-0.319,0] ... (1.15, Inf]

# %%
chisq.test(table(class), p=rep(1/8, 8))
# Out:
# 	Chi-squared test for given probabilities
#
# data:  table(class)
# X-squared = 9.2, df = 7, p-value = 0.2386
